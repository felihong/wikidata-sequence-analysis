# %%
import os
import data_analyser

# %%
os.chdir('../../data')
data = data_analyser.DataAnalyser('article_sample.csv').data

# %%
data
# Out:
#        item_id item_name user_id               user_name user_editcount  \
# 0          114       Q17      13                    Aude          24410
# 1          114       Q17      13                    Aude          24410
# 2          114       Q17      13                    Aude          24410
# 3          114       Q17
# 4          114       Q17    3102    Katie Filbert (WMDE)             33
# 5          114       Q17    3244              Jens Ohlig           1497
# 6          114       Q17    3244              Jens Ohlig           1497
# 7          114       Q17    3248                  Casual            533
# 8          114       Q17     155                  Jeblad           7450
# 9          114       Q17     155                  Jeblad           7450
# 10         114       Q17    3244              Jens Ohlig           1497
# 11         114       Q17    3244              Jens Ohlig           1497
# 12         137       Q24
# ...
